# %%
# %run Ising_Model_Hamiltonian_Function.ipynb

# %% [markdown]
# # N=3 A = [0,2]

# %%
p = np.linspace(0, 10, 100)
points = []
for i in p:
    H = ising_model_hamiltonian(3,1,i,0)
    #print(H)
    E, psi = H.groundstate()
    rhoa = Q.ptrace(psi,[0,2])
    #print(rhoa)
    eigenvals = rhoa.eigenenergies()
    threshold1 = abs(eigenvals) < 10**(-8)
    eigenvals[threshold1] = 0
    #print(eigenvals)
    eigenvalscleaned = [num for num in eigenvals if num != 0]
    #print(eigenvalscleaned)
    vnentropylist = []
    for l in eigenvalscleaned:
        vnentropylist.append(-l*np.log(l))
        #print(vnentropylist)
        vnentropy = sum(vnentropylist)
        #print(vnentropy)
    points.append(vnentropy)

fig, ax = plt.subplots(figsize=(8,8))
plt.plot(p, points, linestyle = "none", marker = "o")
# label the axes
ax.set_xlabel("h value")
ax.set_ylabel("Von Neumann Entropy")

# set the tick mark parameters
ax.minorticks_on()
ax.tick_params(which='both',direction="in",width=1)
ax.tick_params(which='major',length=7)
ax.tick_params(which='minor',length=3.5)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
plt.show()
# Out:
# D:\Applications\Anaconda\Lib\site-packages\qutip\core\qobj.py:1626: UserWarning: Ground state may be degenerate.
#   warnings.warn("Ground state may be degenerate.", UserWarning)

# %% [markdown]
# # N=3 A = [0,1]

# %%
p = np.linspace(0, 10, 100)
points = []
for i in p:
    H = ising_model_hamiltonian(3,1,i,0)
    #print(H)
    E, psi = H.groundstate()
    rhoa = Q.ptrace(psi,[0,1])
    #print(rhoa)
    eigenvals = rhoa.eigenenergies()
    threshold1 = abs(eigenvals) < 10**(-8)
    eigenvals[threshold1] = 0
    #print(eigenvals)
    eigenvalscleaned = [num for num in eigenvals if num != 0]
    #print(eigenvalscleaned)
    vnentropylist = []
    for l in eigenvalscleaned:
        vnentropylist.append(-l*np.log(l))
        #print(vnentropylist)
        vnentropy = sum(vnentropylist)
        #print(vnentropy)
    points.append(vnentropy)
    
fig, ax = plt.subplots(figsize=(8,8))
plt.plot(p, points)
# label the axes
ax.set_xlabel("h value")
ax.set_ylabel("Von Neumann Entropy")

# set the tick mark parameters
ax.minorticks_on()
ax.tick_params(which='both',direction="in",width=1)
ax.tick_params(which='major',length=7)
ax.tick_params(which='minor',length=3.5)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
plt.show()

# %% [markdown]
# # N=3 A = [1]

# %%
p = np.linspace(0, 10, 100)
points = []
for i in p:
    H = ising_model_hamiltonian(3,1,i,0)
    #print(H)
    E, psi = H.groundstate()
    rhoa = Q.ptrace(psi,[1])
    #print(rhoa)
    eigenvals = rhoa.eigenenergies()
    threshold1 = abs(eigenvals) < 10**(-8)
    eigenvals[threshold1] = 0
    #print(eigenvals)
    eigenvalscleaned = [num for num in eigenvals if num != 0]
    #print(eigenvalscleaned)
    vnentropylist = []
    for l in eigenvalscleaned:
        vnentropylist.append(-l*np.log(l))
        #print(vnentropylist)
        vnentropy = sum(vnentropylist)
        #print(vnentropy)
    points.append(vnentropy)
    
fig, ax = plt.subplots(figsize=(8,8))
plt.plot(p, points)
# label the axes
ax.set_xlabel("h value")
ax.set_ylabel("Von Neumann Entropy")

# set the tick mark parameters
ax.minorticks_on()
ax.tick_params(which='both',direction="in",width=1)
ax.tick_params(which='major',length=7)
ax.tick_params(which='minor',length=3.5)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
plt.show()

# %% [markdown]
# # N=8 Half Partition

# %%
p = np.linspace(0, 2, 100)
points = []
for i in p:
    H = ising_model_hamiltonian(8,1,i,0)
    #print(H)
    E, psi = H.groundstate()
    rhoa = Q.ptrace(psi,[0,1,2,3])
    #print(rhoa)
    eigenvals = rhoa.eigenenergies()
    threshold1 = abs(eigenvals) < 10**(-8)
    eigenvals[threshold1] = 0
    #print(eigenvals)
    eigenvalscleaned = [num for num in eigenvals if num != 0]
    #print(eigenvalscleaned)
    vnentropylist = []
    for l in eigenvalscleaned:
        vnentropylist.append(-l*np.log(l))
        #print(vnentropylist)
        vnentropy = sum(vnentropylist)
        #print(vnentropy)
    points.append(vnentropy)
    
fig, ax = plt.subplots(figsize=(8,8))
plt.plot(p, points)
# label the axes
ax.set_xlabel("h value")
ax.set_ylabel("Von Neumann Entropy")

# set the tick mark parameters
ax.minorticks_on()
ax.tick_params(which='both',direction="in",width=1)
ax.tick_params(which='major',length=7)
ax.tick_params(which='minor',length=3.5)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
plt.show()

# %% [markdown]
# ## N = 8 Loop Through

# %%
fig, ax = plt.subplots(figsize=(8,8))
# label the axes
ax.set_xlabel("h value")
ax.set_ylabel("Von Neumann Entropy")

# set the tick mark parameters
ax.minorticks_on()
ax.tick_params(which='both',direction="in",width=1)
ax.tick_params(which='major',length=7)
ax.tick_params(which='minor',length=3.5)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')

p = np.linspace(0, 8, 100)
tracedspins = []
for i in range(7):
    points = []
    tracedspins.append(i)
    for j in p:
        H = ising_model_hamiltonian(8,1,j,0)
        #print(H)
        E, psi = H.groundstate()
        vnentropylist = []
        rhoa = Q.ptrace(psi,tracedspins)
        #print(rhoa)
        eigenvals = rhoa.eigenenergies()
        threshold1 = abs(eigenvals) < 10**(-8)
        eigenvals[threshold1] = 0
        #print(eigenvals)
        eigenvalscleaned = [num for num in eigenvals if num != 0]
        #print(eigenvalscleaned)
        #vnentropylist = []
        for l in eigenvalscleaned:
            vnentropylist.append(-l*np.log(l))
            #print(vnentropylist)
            vnentropy = sum(vnentropylist)
            #print(vnentropy)
        points.append(vnentropy)
    plt.plot(p, points)
    plt.show()
    print("The spins contained in partition A are")
    print(tracedspins)
# Out:
# The spins contained in partition A are
# [0]
# The spins contained in partition A are
# [0, 1]
# The spins contained in partition A are
# [0, 1, 2]
# The spins contained in partition A are
# [0, 1, 2, 3]
# The spins contained in partition A are
# [0, 1, 2, 3, 4]
# The spins contained in partition A are
# [0, 1, 2, 3, 4, 5]
# The spins contained in partition A are
# [0, 1, 2, 3, 4, 5, 6]
