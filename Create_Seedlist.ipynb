# %%
from ProjectFunctions import *

# %%
info = read_from_disk("Bassi_first_data")
seedlist = []
for index, val in enumerate(info):
    if index % 2 == 0:
        seedlist.append(val)

# %%
with open('sorted_bassi_seeds', 'a') as file:
    for seed in seedlist:
        file.write(seed + '\n')
