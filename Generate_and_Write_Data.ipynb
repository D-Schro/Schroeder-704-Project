# %%
from ProjectFunctions import *

# %%
Hfield = sg_field(8)

# %% [markdown]
# # Classical Data

# %%
# %%time
energydict = generate_sorted_classical_data(8, 14, range(100))
save_dict_to_array_file(energydict, 'N8_classical_data_array_short.txt')

# %% [markdown]
# # Quantum Data

# %%
# %%time
length = 8
Hfield = sg_field(8)
hvals = np.arange(0.001, 6, 0.1)
generate_psi_data(8, 14, range(100), Hfield, 0.1)
save_dict_to_array_file(energydict, 'N8_classical_data_array_short.txt')

# %%
# %%time
minfo_dict = generate_mutual_information_data(8, 14, [1,2], Hfield, 0.001)
save_dict_to_array_file(minfo_dict, 'N8_minfo_test.txt')
# Out:
# CPU times: total: 2.23 s
# Wall time: 634 ms

# %%
info = read_transition_data('N8_minfo_test.txt')

# %%
# Out:
# 0.10814449439434794
